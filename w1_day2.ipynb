# %%
#question 1
def is_even(num):
    if num%2==0:
        return "even"
    else:
        return "odd"

for i in range(1,11):
    print(f"{i},and the number is: {is_even(i)}")
# Out:
# 1,and the number is: odd
# 2,and the number is: even
# 3,and the number is: odd
# 4,and the number is: even
# 5,and the number is: odd
# 6,and the number is: even
# 7,and the number is: odd
# 8,and the number is: even
# 9,and the number is: odd
# 10,and the number is: even

# %%
#question 2
l1=[1,4,3,2,5]
l1.sort()  #sorting
num=l1[0]  #smallest in the list

#for i in range(0,5):
    #if l1[i]<num:
        #num=l1[i] # for loop can be used if list not sorted!

l1.remove(num)#removing smallest
print(l1)
# Out:
# [2, 3, 4, 5]

# %%
#question 3
l2=("mehul","vishu","aditya","gauri")
print(l2[0])
print(l2[-1])
# Out:
# mehul
# gauri
